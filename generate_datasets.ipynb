# %%
from solvers import BFSSolverDataset, BFSSolverSimilarDataset
from cube import Cube

solver = BFSSolverDataset(5, 4)
solver2 = BFSSolverSimilarDataset(6, 4)

cube = Cube()
scramble = cube.scramble(9)
print(f"Scramble: {scramble}")

sol = solver(cube)
print(f"Solution: {sol}")
sol2 = solver2(cube)
print(f"Solution2: {sol2}")
# Out:
# Loaded full optimal value dataset from datasets/full/full_5.pt.
# Scramble: [U', L, U', L2, B, D', L', B2, D]
# Solution: [D', B2, L, D, B', L2, U, L', U]
# Solution2: [D', B2, L, D, B', L2, U, L', U]

# %%
from cube_datasets import get_similar_optimal_value_dataset
from solvers import solve_cube_bfs

# %matplotlib inline

dataset = get_similar_optimal_value_dataset(1)

for cube in dataset.keys():
    # print(cube)
    cube.plot_3d()

    print(solve_cube_bfs(cube))
# Out:
# []
# [F']
# [F]
# [F2]
